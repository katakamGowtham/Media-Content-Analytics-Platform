# %%
pip install protobuf==3.20.3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install google-api-python-client
# Out:
# ^C
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/13.1 MB 7.4 MB/s eta 0:00:02
#    -------- ------------------------------- 2.9/13.1 MB 7.6 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/13.1 MB 7.5 MB/s eta 0:00:02
#    --------------------- ------------------ 7.1/13.1 MB 8.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/13.1 MB 8.1 MB/s eta 0:00:01
# ...

# %%
pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

# Step 1: Setup API
API_KEY = 'AIzaSyBlfCkTh4Wq4zRnxJw9KZojNpZ_usKyI8E' 
youtube = build('youtube', 'v3', developerKey=API_KEY)

# Step 2: Get Channel Uploads Playlist ID
channel_request = youtube.channels().list(
    part='contentDetails',
    id='UC_x5XG1OV2P6uZZ5FSM9Ttw'  # Replace with target channel ID
)
channel_response = channel_request.execute()

playlist_id = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

# Step 3: Extract All Video IDs with Pagination
video_ids = []
next_page_token = None

while True:
    videos_request = youtube.playlistItems().list(
        part='snippet',
        playlistId=playlist_id,
        maxResults=50,
        pageToken=next_page_token
    )
    videos_response = videos_request.execute()

    # Extract video IDs
    for item in videos_response['items']:
        video_ids.append(item['snippet']['resourceId']['videoId'])

    # Check if there are more pages
    next_page_token = videos_response.get('nextPageToken')
    if not next_page_token:
        break  # Exit loop

print(f"Total Videos Extracted: {len(video_ids)}")

# Step 4: Get Video Statistics for Each Video
video_data = []
for i in range(0, len(video_ids), 50):  # YouTube API allows max 50 videos per request
    videos_stats_request = youtube.videos().list(
        part="snippet,statistics,contentDetails",
        id=",".join(video_ids[i:i+50])
    )
    videos_stats_response = videos_stats_request.execute()

    for item in videos_stats_response['items']:
        video_data.append({
            'video_id': item['id'],
            'title': item['snippet']['title'],
            'duration': item['contentDetails']['duration'],  # Format: PT5M30S
            'view_count': item['statistics'].get('viewCount', 0),
            'like_count': item['statistics'].get('likeCount', 0),
            'comment_count': item['statistics'].get('commentCount', 0),
            'tags': ",".join(item['snippet'].get('tags', [])) if 'tags' in item['snippet'] else "None"
        })


print()
# Out:
# Total Videos Extracted: 6486

# %%
import pandas as pd

# Create a Pandas DataFrame
df = pd.DataFrame(video_data)

# Display DataFrame
print(df)
# Out:
#          video_id                                              title  \
# 0     fys-Rr6eoKo                 Building a travel buddy with Gemma
# 1     BgWO2iVPlyw                       What’s new in ShieldGemma 2?
# 2     UU13FN2Xpyw                             What’s new in Gemma 3?
# 3     I-4GShiD1yY               Different bugs. Different reactions.
# 4     zmg41WdIz30  What separates a junior engineer from a senior...
# ...           ...                                                ...
# 6481  5Eib_H_zCEY          Cluster Computing and MapReduce Lecture 3
# 6482  yjPBkvYh-ss          Cluster Computing and MapReduce Lecture 1
# 6483  -vD6PUdf3Js          Cluster Computing and MapReduce Lecture 2
# 6484  1ZDybXl212Q          Cluster Computing and MapReduce Lecture 4
# 6485  F59KmOrnFco                       Gearing up with Zoho Offline
#
#       duration view_count like_count comment_count  \
# 0      PT2M52S       6653        235            29
# ...

# %%
#Save to CSV for further analysis

df.to_csv("youtube_video_data.csv", index=False)

# %%
pip install clyent==1.2.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nbformat==5.4.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle

# %%
kaggle.api.authenticate()
kaggle.api.dataset_download_files('rmisra/news-category-dataset', path='./data',
unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rmisra/news-category-dataset

# %%
import json

# %%
news_data = []
with open('./data/News_Category_Dataset_v3.json', 'r') as f:
    for line in f:
        news_data.append(json.loads(line))

# %%
import pandas as pd
news_df = pd.DataFrame(news_data)
news_df
# Out:
#                                                      link  \
# 0       https://www.huffpost.com/entry/covid-boosters-...
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# ...

# %%
news_df.to_csv("./data/News_Category_Dataset_v3.csv")

# %%
news_df.to_csv("News_Category_Dataset_v3.csv")

# %%
from googleapiclient.discovery import build
import pandas as pd

# Step 1: Setup YouTube API
API_KEY = "AIzaSyBlfCkTh4Wq4zRnxJw9KZojNpZ_usKyI8E"
youtube = build("youtube", "v3", developerKey=API_KEY)

# Step 2: Fetch Videos Using YouTube Search API
def get_uploaded_videos(query, max_results=1000):
    video_ids = []
    next_page_token = None

    while len(video_ids) < max_results:
        search_request = youtube.search().list(
            part="id",
            q=query,  # Search for videos (change topic if needed)
            type="video",
            order="date",  # Get latest videos first
            maxResults=50,  # Max per request
            pageToken=next_page_token
        )
        search_response = search_request.execute()

        # Extract Video IDs
        for item in search_response.get("items", []):
            video_ids.append(item["id"]["videoId"])

        # Check if there are more pages
        next_page_token = search_response.get("nextPageToken")
        if not next_page_token:
            break  # No more results

    return video_ids[:max_results]  # Limit to max_results

# Step 3: Fetch Video Statistics
def get_video_details(video_ids):
    video_data = []
    
    for i in range(0, len(video_ids), 50):  # API allows max 50 videos per request
        videos_request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=",".join(video_ids[i:i+50])
        )
        videos_response = videos_request.execute()

        for item in videos_response["items"]:
            video_data.append({
                "video_id": item["id"],
                "title": item["snippet"]["title"],
                "channel": item["snippet"]["channelTitle"],
                "published_at": item["snippet"]["publishedAt"],
                "duration": item["contentDetails"]["duration"],  # Format: PT5M30S
                "view_count": item["statistics"].get("viewCount", 0),
                "like_count": item["statistics"].get("likeCount", 0),
                "comment_count": item["statistics"].get("commentCount", 0),
                "tags": ",".join(item["snippet"].get("tags", [])) if "tags" in item["snippet"] else "None"
            })

    return video_data

# Run the Search and Fetch Video Data
query = "latest news"  # Change this to any keyword
video_ids = get_uploaded_videos(query, max_results=1000)
print(f"Total Videos Extracted: {len(video_ids)}")

video_data = get_video_details(video_ids)
df = pd.DataFrame(video_data)

# Save to CSV
df.to_csv("youtube_uploaded_videos.csv", index=False)
print(" Data saved successfully!")
# Out:
# Total Videos Extracted: 601
#  Data saved successfully!

# %%
from googleapiclient.discovery import build
api_key = 'AIzaSyBB9VKgImAsx1NiakwXV-u2l4Mm20W5rVs'

channel_ids = [" UCq-Fj5jknLsUf-MWSy4_brA", #Tseris
               "UCupvZG-5ko_eiXAupbDfxWw", #Cnn
               "UCvC4D8onUfXzvjTOM-dBfEA", #Marvel
               "UCMiJRAwDNSNzuYeN2uWa0pA", #Techchannel
               "UCYPvAwZP8pZhSMW8qs7cVCw", #India Today
               "UCb-xXZ7ltTvrh9C6DgB9H-Q",#Prasd Tech in telugu
               "UCBi2mrWuNuyYy4gbM6fU18Q",#ABC NEws
               "UCnQC_G5Xsjhp9fEJKuIcrSw",#Benshapiro
               "UCXuqSBlHAE6Xw-yeJA0Tunw", #LinusTech
               "UCsTcErHg8oDvUnTzoqsYeNw",#Unboxtheropy
               "UCOmcA3f_RrH6b9NmcNa4tdg",#CNET
               "UCOpcACMWblDls9Z6GERVi1A",#Screen Junkies
               "UCVtL1edhT8qqY-j2JIndMzg",#CineFix
               "UCLXo7UDZvByw2ixzpQCufnA",#Vox
               "UCvJJ_dzjViJCoLf5uKUTwoA",#CNBC
               "CoUxsWakJucWg46KW5RsvPw",#Financial
               "UCX6b17PVsYBQ0ip5gyeme-Q",#CrashCourse
               "UC4a-Gbdw7vOaccHmFo40b9g",#Khan Academy
               "UCsooa4yRKGN_zEE8iknghZA",#Ted-ed
               "UCq2E1mIwUKMWzCA4liA_XGQ",#PickUpLimes
               "UCJ24N4O0bP7LGLBDvye7oCA",#Matt
               "UCSPYNpQ2fHv9HJ-q6MIMaPw",#Financialdiet
               "UCFKE7WVJfvaHW5q283SxchA",#Yoga with Adriene
              ]

youtube = build('youtube', 'v3', developerKey=api_key)

def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
import pandas as pd
channel_data = pd.DataFrame(channel_statistics)
channel_data
# Out:
#                    Channel_name Subscribers         Views Total_videos  \
# 0            Prasadtechintelugu     4750000    1795326121         4670
# 1                      ABC News    18300000   16356416062        98666
# 2                 Pick Up Limes     4370000     295373645          232
# 3                           Vox    12500000    3670018009         1788
# 4                Screen Junkies     6770000    3010782902         1460
# 5                           CNN    17800000   17539093528       170258
# 6               Linus Tech Tips    16200000    8546011960         7221
# 7                          CNET     3960000    1899160408        23220
# 8                      T-Series   288000000  289000349464        22903
# 9                   India Today    10100000    4550899673       227179
# 10                       TED-Ed    21200000    4226836680         2239
# 11                Matt D'Avella     3910000     311765298          435
# ...

# %%
def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name']=='Vox', 'playlist_id'].iloc[0]
video_ids = get_video_ids(youtube, playlist_id)
video_ids
# Out:
# ['cTS5o8uYGpY',
#  '47GYyXVTUFY',
#  'a9vPm615xnY',
#  'r4AsZYIn6Ug',
#  'OBFX4EuAWHc',
#  'wW2pl16wHtY',
#  'anAaMO9s0G0',
#  '5dQglrj0Cts',
#  'DKTcrYVSgFY',
#  'UBc38VjI7NU',
#  'U326f2w1hjI',
#  '0wGIl2KDJrQ',
#  'IZWQonLN2xk',
#  'QS7MOe_YTUw',
#  'Ct-XZmv9r8I',
#  'oD6_JGO8Zpk',
#  'HSJcnUUJlPA',
#  '2XkV-AMhBvo',
#  'bcGxg3c1HE8',
#  'g4lyP-1qoWY',
#  'eejvKLS8Ssk',
#  'KSj0NFl0vlo',
#  'w60cCr4V5UM',
#  'OuZSs3N1hII',
#  'ZGk-rH_zcPE',
#  '7h42PqYosKI',
#  'hvAigEXWSYM',
#  'BtenhrVXhRA',
#  'VtTLUnH5vps',
#  'CSrswEQxtnA',
#  'uT8GMsWx_yE',
#  'eNmgYjlP1w4',
#  '8KjVmoBi2CM',
#  'VVDKRz3r5jg',
#  'SMXJ-qx54x4',
#  'gK6MD_8S01o',
#  'In9Pqm9YlIo',
#  'rq9dhQIoDw8',
#  'gadrvwAVorA',
#  'G8SK6e8I01Y',
#  'vPO-2BXUuKI',
#  'Zti0hEurEIo',
#  'mcoiOY3ZOVo',
#  'KBS-4qWJ8s4',
#  'Js-hZPtspJc',
#  'YGfJeH5HRDQ',
#  'JO6xQ5o_XeM',
#  'uhx1sdX2bow',
#  'cyMYtNaB9NU',
#  'k-a0EFhr3vE',
#  'SSzFWja6dLE',
#  '5qmxHJUmW5c',
#  '3tz2BUuzTmE',
#  'n0lGa5oCCEY',
#  '3DKVwu8mOsY',
# ...

# %%
# Dictionary to store video IDs for each channel
channel_videos = {}

# Iterate through all rows in channel_data
for index, row in channel_data.iterrows():
    playlist_id = row['playlist_id']
    channel_name = row['Channel_name']
    
    # Fetch video IDs for the current playlist
    video_ids = get_video_ids(youtube, playlist_id)
    
    # Store the result in the dictionary
    channel_videos[channel_name] = video_ids

# Print or use channel_videos as needed
channel_videos
# Out:
# {'Prasadtechintelugu': ['yz4JVEUUgkQ',
#   'pgvaeIlzN2g',
#   'jib5jeAI9Ak',
#   'K7DfNqX6m9k',
#   'DjEff2JkVcs',
#   'Cp3rVi-yFVk',
#   'uuOTUgvaqVo',
#   'imjDpcT2xfg',
#   'TAWv2hUWV3Q',
#   't80zwUDIMFM',
#   'sbphTOCqI4s',
#   'Lgzj_8zx4uo',
#   'OZNUJdyRXm4',
#   'odmkeTh4tvc',
#   'E8mrs-nFXsU',
#   'Mv8XCUsSwsw',
#   'jPgIM-pZbEQ',
#   'TZg8XLIMCQ0',
#   'NS3XNXSjKns',
#   'mClig78zOPg',
#   '66Pk-b43EBM',
#   '19yId30S66k',
#   'tWtBrk99LFU',
#   'LrQ7bT7fTV4',
#   '40kjWu-76cM',
#   'gVbnKY4xWwM',
#   'bbUXlFDWCJY',
#   'LYuS1uDNMRk',
#   'CSjKEzJSkTA',
#   'fljoAHvlgDs',
#   '-fnjgBNIbRM',
#   'EhbC68maoGc',
#   'dMWEzgtTeqk',
#   'HxpV4q2Mg08',
#   '6ypFfuKj_MQ',
#   'ayZdc8R00bI',
#   'hMWxbNTt610',
#   '72AZt7wnmx4',
#   'f0NNBJ1ISKk',
#   '7wQ-sMojqrs',
#   'HMnTXazK6DA',
#   'Dw1deHNzNXQ',
#   'CzojwPHJQ1c',
#   'whk-Try-blY',
#   'uPomPVBqJ_o',
#   'ihu--10Z2i4',
#   'aVlqNu8P50Y',
#   'uvvXg2dvMls',
#   '7XBrXLdKj8k',
#   'CjYM_38xKI0',
#   '8D33beayBzY',
# ...

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):  # YouTube API allows max 50 videos per request
        request = youtube.videos().list(
            part="snippet,statistics",
            id=",".join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response.get("items", []):  # Prevent KeyError if 'items' is missing
            video_stats = dict(
                Title=video["snippet"]["title"],
                Published_date=video["snippet"]["publishedAt"],
                Views=video["statistics"].get("viewCount", 0),  # .get() to handle missing data
                Likes=video["statistics"].get("likeCount", 0),
                Comments=video["statistics"].get("commentCount", 0),  # Removed 'dislikeCount'video
                category = video["snippet"]["categoryId"]            
            )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
type(channel_videos)
# Out:
# dict

# %%
type(video_ids)
# Out:
# list

# %%
def get_video_details(youtube, video_ids, max_requests=10):
    all_video_stats = []
    request_count = 0  # Track API requests
    
    for i in range(0, min(len(video_ids), max_requests * 50), 50):  # Limit number of requests
        if request_count >= max_requests:
            print("Reached max API request limit. Stopping...")
            break
        
        request = youtube.videos().list(
            part="snippet,statistics",
            id=",".join(video_ids[i:i+50])
        )
        response = request.execute()
        request_count += 1  # Increment request count

        for video in response.get("items", []):
            video_stats = dict(
                Title=video["snippet"]["title"],
                Published_date=video["snippet"]["publishedAt"],
                Views=video["statistics"].get("viewCount", 0),
                Likes=video["statistics"].get("likeCount", 0),
                Comments=video["statistics"].get("commentCount", 0)
            )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
df = pd.read_csv("News_Category_Dataset_v3.csv")
df
# Out:
#         Unnamed: 0                                               link  \
# 0                0  https://www.huffpost.com/entry/covid-boosters-...
# 1                1  https://www.huffpost.com/entry/american-airlin...
# 2                2  https://www.huffpost.com/entry/funniest-tweets...
# 3                3  https://www.huffpost.com/entry/funniest-parent...
# 4                4  https://www.huffpost.com/entry/amy-cooper-lose...
# ...            ...                                                ...
# 209522      209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523      209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524      209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525      209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526      209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category  \
# ...
